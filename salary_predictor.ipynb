# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data.csv')

# %%
data.shape
# Out:
# (742, 28)

# %%
data.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
data = data.drop(['company_txt','job_state','same_state','python_yn','R_yn','spark','aws','excel','min_salary','max_salary'], axis=1)

# %%
data.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
data= data.drop(['hourly','Industry'], axis=1)

# %%
data.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
data= data.drop(['employer_provided','Headquarters'], axis=1)

# %%
data.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
data= data.drop(['Salary Estimate'], axis=1)

# %%
data.head()
# Out:
#                    Job Title  \
# 0             Data Scientist
# 1  Healthcare Data Scientist
# 2             Data Scientist
# 3             Data Scientist
# 4             Data Scientist
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# 2                                KnowBe4\n4.8   Clearwater, FL
# 3                                   PNNL\n3.8     Richland, WA
# 4                     Affinity Solutions\n2.9     New York, NY
#
# ...

# %%
data.isnull().sum()
# Out:
# Job Title            0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Size                 0
# Founded              0
# Type of ownership    0
# Sector               0
# Revenue              0
# Competitors          0
# avg_salary           0
# age                  0
# dtype: int64

# %%
data['Type of ownership'].value_counts()
# Out:
# Company - Private                 410
# Company - Public                  193
# Nonprofit Organization             55
# Subsidiary or Business Segment     34
# Government                         15
# Hospital                           15
# College / University               13
# Other Organization                  3
# School / School District            2
# Unknown                             1
# -1                                  1
# Name: Type of ownership, dtype: int64

# %%
data = data[data['Size'] != 'Unknown']

# %%
data['Size'].value_counts()
# Out:
# 1001 to 5000 employees     150
# 501 to 1000 employees      134
# 10000+ employees           130
# 201 to 500 employees       117
# 51 to 200 employees         94
# 5001 to 10000 employees     76
# 1 to 50 employees           31
# -1                           1
# Name: Size, dtype: int64

# %%
data = data[data['Size'] != '-1']

# %%
data['Size'] = data['Size'].str.replace('employees', '')

# %%
data['Size'].value_counts()
# Out:
# 1001 to 5000      150
# 501 to 1000       134
# 10000+            130
# 201 to 500        117
# 51 to 200          94
# 5001 to 10000      76
# 1 to 50            31
# Name: Size, dtype: int64

# %%
def extract_average(s):
    if '+' in s:
        return int(s.replace('+', ''))
    elif ' to ' in s:
        a, b = s.split(' to ')
        return (int(a) + int(b)) // 2
    else:
        return int(s)

# %%
data['Size'] = data['Size'].apply(extract_average)

# %%
data['Size']
# Out:
# 0        750
# 1      10000
# 2        750
# 3       3000
# 4        125
#        ...
# 737    10000
# 738     3000
# 739      750
# 740       25
# 741      750
# Name: Size, Length: 732, dtype: int64

# %%
data.head()
# Out:
#                    Job Title  \
# 0             Data Scientist
# 1  Healthcare Data Scientist
# 2             Data Scientist
# 3             Data Scientist
# 4             Data Scientist
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location   Size  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM    750
# 1  University of Maryland Medical System\n3.4    Linthicum, MD  10000
# 2                                KnowBe4\n4.8   Clearwater, FL    750
# 3                                   PNNL\n3.8     Richland, WA   3000
# ...

# %%
data['Revenue']
# Out:
# 0             $50 to $100 million (USD)
# 1                $2 to $5 billion (USD)
# 2            $100 to $500 million (USD)
# 3      $500 million to $1 billion (USD)
# 4              Unknown / Non-Applicable
#                      ...
# 737                  $10+ billion (USD)
# 738          $100 to $500 million (USD)
# 739            Unknown / Non-Applicable
# 740             $5 to $10 million (USD)
# 741           $50 to $100 million (USD)
# Name: Revenue, Length: 732, dtype: object

# %%
data['Revenue'].value_counts()
# Out:
# Unknown / Non-Applicable            194
# $10+ billion (USD)                  124
# $100 to $500 million (USD)           91
# $1 to $2 billion (USD)               60
# $500 million to $1 billion (USD)     57
# $50 to $100 million (USD)            46
# $25 to $50 million (USD)             40
# $2 to $5 billion (USD)               39
# $10 to $25 million (USD)             32
# $5 to $10 billion (USD)              19
# $5 to $10 million (USD)              18
# $1 to $5 million (USD)                8
# Less than $1 million (USD)            4
# Name: Revenue, dtype: int64

# %%
def remove_units(s):
    s = s.replace(' billion (USD)', '')
    s = s.replace(' million (USD)', '')
    return s

# %%
data['Revenue'] = data['Revenue'].apply(remove_units)

# %%
data['Revenue'].value_counts()
# Out:
# Unknown / Non-Applicable    194
# $10+                        124
# $100 to $500                 91
# $1 to $2                     60
# $500 million to $1           57
# $50 to $100                  46
# $25 to $50                   40
# $2 to $5                     39
# $5 to $10                    37
# $10 to $25                   32
# $1 to $5                      8
# Less than $1                  4
# Name: Revenue, dtype: int64

# %%
data = data[data['Revenue'] != 'Less than $1']

# %%
data['Revenue'].value_counts()
# Out:
# Unknown / Non-Applicable    194
# $10+                        124
# $100 to $500                 91
# $1 to $2                     60
# $500 million to $1           57
# $50 to $100                  46
# $25 to $50                   40
# $2 to $5                     39
# $5 to $10                    37
# $10 to $25                   32
# $1 to $5                      8
# Name: Revenue, dtype: int64

# %%
data['Revenue'] = data['Revenue'].str.replace(' million', '', regex=False)

# %%
data['Revenue'].value_counts()
# Out:
# Unknown / Non-Applicable    194
# $10+                        124
# $100 to $500                 91
# $1 to $2                     60
# $500 to $1                   57
# $50 to $100                  46
# $25 to $50                   40
# $2 to $5                     39
# $5 to $10                    37
# $10 to $25                   32
# $1 to $5                      8
# Name: Revenue, dtype: int64

# %%
data['Revenue'] = data['Revenue'].str.replace('$', '', regex=False)

# %%
data['Revenue'].value_counts()
# Out:
# Unknown / Non-Applicable    194
# 10+                         124
# 100 to 500                   91
# 1 to 2                       60
# 500 to 1                     57
# 50 to 100                    46
# 25 to 50                     40
# 2 to 5                       39
# 5 to 10                      37
# 10 to 25                     32
# 1 to 5                        8
# Name: Revenue, dtype: int64

# %%
data['Revenue'] = data['Revenue'].str.replace('+', '', regex=False)

# %%
data['Revenue'] = data['Revenue'].str.replace(' / Non-Applicable', '', regex=False)

# %%
data['Revenue'] = data['Revenue'].str.replace('Unknown', '700', regex=False)

# %%
data['Revenue'] = data['Revenue'].apply(lambda x: (int(x.split()[0]) + int(x.split()[2])) / 2 if 'to' in x else int(x))

# %%
data['Revenue']
# Out:
# 0       75.0
# 1        3.5
# 2      300.0
# 3      250.5
# 4      700.0
#        ...
# 737     10.0
# 738    300.0
# 739    700.0
# 740      7.5
# 741     75.0
# Name: Revenue, Length: 728, dtype: float64

# %%
data.shape
# Out:
# (728, 13)

# %%
data.head()
# Out:
#                    Job Title  \
# 0             Data Scientist
# 1  Healthcare Data Scientist
# 2             Data Scientist
# 3             Data Scientist
# 4             Data Scientist
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location   Size  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM    750
# 1  University of Maryland Medical System\n3.4    Linthicum, MD  10000
# 2                                KnowBe4\n4.8   Clearwater, FL    750
# 3                                   PNNL\n3.8     Richland, WA   3000
# ...

# %%
data = data.drop("Sector", axis=1)

# %%
data.head()
# Out:
#                    Job Title  \
# 0             Data Scientist
# 1  Healthcare Data Scientist
# 2             Data Scientist
# 3             Data Scientist
# 4             Data Scientist
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location   Size  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM    750
# 1  University of Maryland Medical System\n3.4    Linthicum, MD  10000
# 2                                KnowBe4\n4.8   Clearwater, FL    750
# 3                                   PNNL\n3.8     Richland, WA   3000
# ...

# %%
data['Competitors'].value_counts()
# Out:
# -1                                                                                              446
# Novartis, Baxter, Pfizer                                                                         14
# Oak Ridge National Laboratory, National Renewable Energy Lab, Los Alamos National Laboratory     12
# Travelers, Allstate, State Farm                                                                  10
# Roche, GlaxoSmithKline, Novartis                                                                  9
#                                                                                                ...
# BrowserStack, Selenium Master, Perfecto Mobile                                                    1
# Boeing, Northrop Grumman, Raytheon                                                                1
# Unilever, Procter & Gamble, Henkel                                                                1
# ...

# %%
data = data.drop("Competitors", axis=1)

# %%
data.head()
# Out:
#                    Job Title  \
# 0             Data Scientist
# 1  Healthcare Data Scientist
# 2             Data Scientist
# 3             Data Scientist
# 4             Data Scientist
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location   Size  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM    750
# 1  University of Maryland Medical System\n3.4    Linthicum, MD  10000
# 2                                KnowBe4\n4.8   Clearwater, FL    750
# 3                                   PNNL\n3.8     Richland, WA   3000
# ...

# %%
data['Company Name'].value_counts()
# Out:
# MassMutual\n3.6                                         14
# Reynolds American\n3.1                                  14
# Takeda Pharmaceuticals\n3.7                             14
# Software Engineering Institute\n2.6                     11
# PNNL\n3.8                                               10
#                                                         ..
# Spectrum Communications and Consulting\n3.4              1
# Dayton Freight Lines, Inc.\n4.3                          1
# Community Action Partnership of San Luis Obispo\n2.8     1
# TrueAccord\n3.4                                          1
# Fivestars\n3.9                                           1
# Name: Company Name, Length: 335, dtype: int64

# %%
data['Company Name'] = data['Company Name'].apply(lambda x: x.split('\n')[0])

# %%
data['Location'] = data['Location'].apply(lambda x: x.split(',')[0])

# %%
data.head()
# Out:
#                    Job Title  \
# 0             Data Scientist
# 1  Healthcare Data Scientist
# 2             Data Scientist
# 3             Data Scientist
# 4             Data Scientist
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                             Company Name     Location   Size  Founded  \
# 0                      Tecolote Research  Albuquerque    750     1973
# 1  University of Maryland Medical System    Linthicum  10000     1984
# 2                                KnowBe4   Clearwater    750     2010
# 3                                   PNNL     Richland   3000     1965
# ...

# %%
data['Type of ownership'].value_counts()
# Out:
# Company - Private                 397
# Company - Public                  193
# Nonprofit Organization             55
# Subsidiary or Business Segment     34
# Government                         15
# Hospital                           15
# College / University               13
# Other Organization                  3
# School / School District            2
# Unknown                             1
# Name: Type of ownership, dtype: int64

# %%
data['Type of ownership'] = data['Type of ownership'].str.replace('Company - ', '', regex=False)
data['Type of ownership'] = data['Type of ownership'].str.replace(' / University', '', regex=False)
data['Type of ownership'] = data['Type of ownership'].str.replace(' / School District', '', regex=False)

# %%
data['Type of ownership'] = data['Type of ownership'].apply(lambda x: x if x in ['Private', 'Public'] else 'Other')

# %%
data.head()
# Out:
#                    Job Title  \
# 0             Data Scientist
# 1  Healthcare Data Scientist
# 2             Data Scientist
# 3             Data Scientist
# 4             Data Scientist
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                             Company Name     Location   Size  Founded  \
# 0                      Tecolote Research  Albuquerque    750     1973
# 1  University of Maryland Medical System    Linthicum  10000     1984
# 2                                KnowBe4   Clearwater    750     2010
# 3                                   PNNL     Richland   3000     1965
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 728 entries, 0 to 741
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          728 non-null    object
#  1   Job Description    728 non-null    object
#  2   Rating             728 non-null    float64
#  3   Company Name       728 non-null    object
#  4   Location           728 non-null    object
#  5   Size               728 non-null    int64
#  6   Founded            728 non-null    int64
#  7   Type of ownership  728 non-null    object
#  8   Revenue            728 non-null    float64
#  9   avg_salary         728 non-null    float64
#  10  age                728 non-null    int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 68.2+ KB

# %%
counts = data['Job Title'].value_counts()

# %%
data['Job Title'].value_counts()
# Out:
# Data Scientist                            125
# Data Engineer                              52
# Senior Data Scientist                      34
# Data Analyst                               15
# Senior Data Engineer                       14
#                                          ...
# Senior Data Scientist Statistics            1
# MongoDB Data Engineer II                    1
# Customer Data Scientist/Sales Engineer      1
# Data Scientist - Bioinformatics             1
# Machine Learning Engineer (NLP)             1
# Name: Job Title, Length: 260, dtype: int64

# %%
counts = data['Job Title'].value_counts()

# %%
data['Job Title'] = data['Job Title'].apply(lambda x: 'Other' if counts[x] <= 5 else x)

# %%
data['Job Title'] = data['Job Title'].str.replace('Sr. Data Engineer', 'Senior Data Scientist', regex=False)
data['Job Title'] = data['Job Title'].str.replace('Senior Data Analyst', 'Senior Data Scientist', regex=False)

# %%
data['Job Title'] = data['Job Title'].str.replace('Senior Data Engineer', 'Senior Data Scientist', regex=False)

# %%
data['Job Title'] = data['Job Title'].str.replace('Data Analyst', 'Data Engineer', regex=False)

# %%
data['Job Title'] = data['Job Title'].str.replace('Data Engineer', 'Data Scientist', regex=False)

# %%
data['Job Title'] = data['Job Title'].str.replace('Other', 'Junior Data Scientist', regex=False)

# %%
data['Job Title'] = data['Job Title'].str.replace('Lead Data Scientist', 'Senior Data Scientist', regex=False)

# %%
data['Job Title'] = data['Job Title'].str.replace('Data Scientist', 'Senior Data Scientist', regex=False)

# %%
data['Job Title'] = data['Job Title'].str.replace('Senior Senior Data Scientist', 'Senior Data Scientist', regex=False)

# %%
data['Job Title'] = data['Job Title'].str.replace('Marketing Senior Data Scientist', 'Senior Data Scientist', regex=False)

# %%
data['Job Title'] = data['Job Title'].str.replace('Junior Senior Data Scientist', 'Junior Data Scientist', regex=False)

# %%
data.head()
# Out:
#                Job Title                                    Job Description  \
# 0  Senior Data Scientist  Data Scientist\nLocation: Albuquerque, NM\nEdu...
# 1  Junior Data Scientist  What You Will Do:\n\nI. General Summary\n\nThe...
# 2  Senior Data Scientist  KnowBe4, Inc. is a high growth information sec...
# 3  Senior Data Scientist  *Organization and Job ID**\nJob ID: 310709\n\n...
# 4  Senior Data Scientist  Data Scientist\nAffinity Solutions / Marketing...
#
#    Rating                           Company Name     Location   Size  Founded  \
# 0     3.8                      Tecolote Research  Albuquerque    750     1973
# 1     3.4  University of Maryland Medical System    Linthicum  10000     1984
# 2     4.8                                KnowBe4   Clearwater    750     2010
# 3     3.8                                   PNNL     Richland   3000     1965
# 4     2.9                     Affinity Solutions     New York    125     1998
#
# ...

# %%
data['Job Description'] = data['Job Description'].str.replace('\n', '', regex=False)

# %%
import nltk
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y = []
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
data['Job Description'] = data['Job Description'].apply(stem)

# %%
data['Job Title'] = data['Job Title'].str.replace('Senior Data Scientist', '1', regex=False)
data['Job Title'] = data['Job Title'].str.replace('Junior Data Scientist', '0', regex=False)

# %%
data['Job Title'] = data['Job Title'].astype(int)

# %%
data.head()
# Out:
#    Job Title                                    Job Description  Rating  \
# 0          1  data scientistlocation: albuquerque, nmeduc re...     3.8
# 1          0  what you will do:i. gener summaryth healthcar ...     3.4
# 2          1  knowbe4, inc. is a high growth inform secur co...     4.8
# 3          1  *organ and job id**job id: 310709directorate: ...     3.8
# 4          1  data scientistaffin solut / market cloud seek ...     2.9
#
#                             Company Name     Location   Size  Founded  \
# 0                      Tecolote Research  Albuquerque    750     1973
# 1  University of Maryland Medical System    Linthicum  10000     1984
# 2                                KnowBe4   Clearwater    750     2010
# 3                                   PNNL     Richland   3000     1965
# 4                     Affinity Solutions     New York    125     1998
#
#   Type of ownership  Revenue  avg_salary  age
# 0           Private     75.0        72.0   47
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 728 entries, 0 to 741
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          728 non-null    int64
#  1   Job Description    728 non-null    object
#  2   Rating             728 non-null    float64
#  3   Company Name       728 non-null    object
#  4   Location           728 non-null    object
#  5   Size               728 non-null    int64
#  6   Founded            728 non-null    int64
#  7   Type of ownership  728 non-null    object
#  8   Revenue            728 non-null    float64
#  9   avg_salary         728 non-null    float64
#  10  age                728 non-null    int64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 68.2+ KB

# %%
data['Type of ownership'].value_counts()
# Out:
# Private    397
# Public     193
# Other      138
# Name: Type of ownership, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBRegressor
from sklearn import metrics

# %%
encoder = LabelEncoder()

# %%
data['Type of ownership'] = encoder.fit_transform(data['Type of ownership'])

# %%
data['Location'].value_counts()
# Out:
# New York         54
# San Francisco    47
# Cambridge        41
# Chicago          32
# Boston           23
#                  ..
# San Ramon         1
# Pella             1
# Agoura Hills      1
# Oak Ridge         1
# Olympia           1
# Name: Location, Length: 195, dtype: int64

# %%
data['Location'] = encoder.fit_transform(data['Location'])

# %%
data.head()
# Out:
#    Job Title                                    Job Description  Rating  \
# 0          1  data scientistlocation: albuquerque, nmeduc re...     3.8
# 1          0  what you will do:i. gener summaryth healthcar ...     3.4
# 2          1  knowbe4, inc. is a high growth inform secur co...     4.8
# 3          1  *organ and job id**job id: 310709directorate: ...     3.8
# 4          1  data scientistaffin solut / market cloud seek ...     2.9
#
#                             Company Name  Location   Size  Founded  \
# 0                      Tecolote Research         3    750     1973
# 1  University of Maryland Medical System        96  10000     1984
# 2                                KnowBe4        40    750     2010
# 3                                   PNNL       151   3000     1965
# 4                     Affinity Solutions       119    125     1998
#
#    Type of ownership  Revenue  avg_salary  age
# 0                  1     75.0        72.0   47
# ...

# %%
data['Company Name'].value_counts()
# Out:
# MassMutual                                         14
# Reynolds American                                  14
# Takeda Pharmaceuticals                             14
# Software Engineering Institute                     11
# PNNL                                               10
#                                                    ..
# Spectrum Communications and Consulting              1
# Dayton Freight Lines, Inc.                          1
# Community Action Partnership of San Luis Obispo     1
# TrueAccord                                          1
# Fivestars                                           1
# Name: Company Name, Length: 335, dtype: int64

# %%
data['Company Name'] = encoder.fit_transform(data['Company Name'])

# %%
data.head()
# Out:
#    Job Title                                    Job Description  Rating  \
# 0          1  data scientistlocation: albuquerque, nmeduc re...     3.8
# 1          0  what you will do:i. gener summaryth healthcar ...     3.4
# 2          1  knowbe4, inc. is a high growth inform secur co...     4.8
# 3          1  *organ and job id**job id: 310709directorate: ...     3.8
# 4          1  data scientistaffin solut / market cloud seek ...     2.9
#
#    Company Name  Location   Size  Founded  Type of ownership  Revenue  \
# 0           287         3    750     1973                  1     75.0
# 1           312        96  10000     1984                  0      3.5
# 2           162        40    750     2010                  1    300.0
# 3           212       151   3000     1965                  0    250.5
# 4            12       119    125     1998                  1    700.0
#
#    avg_salary  age
# 0        72.0   47
# 1        87.5   36
# 2        85.0   10
# 3        76.5   55
# ...

# %%
import string
def remove_punctuation(text):
    return text.translate(str.maketrans('', '', string.punctuation))

# %%
data['Job Description'] = data['Job Description'].apply(lambda x: remove_punctuation(x))

# %%
data.head()
# Out:
#    Job Title                                    Job Description  Rating  \
# 0          1  data scientistlocation albuquerque nmeduc requ...     3.8
# 1          0  what you will doi gener summaryth healthcar da...     3.4
# 2          1  knowbe4 inc is a high growth inform secur comp...     4.8
# 3          1  organ and job idjob id 310709directorate earth...     3.8
# 4          1  data scientistaffin solut  market cloud seek s...     2.9
#
#    Company Name  Location   Size  Founded  Type of ownership  Revenue  \
# 0           287         3    750     1973                  1     75.0
# 1           312        96  10000     1984                  0      3.5
# 2           162        40    750     2010                  1    300.0
# 3           212       151   3000     1965                  0    250.5
# 4            12       119    125     1998                  1    700.0
#
#    avg_salary  age
# 0        72.0   47
# 1        87.5   36
# 2        85.0   10
# 3        76.5   55
# ...

# %%
my_var = data['Job Description'].values

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
vectorizer.fit(my_var)
my_var = vectorizer.transform(my_var)

# %%
type(my_var)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
data['Job Description'] = my_var.toarray()

# %%
data.head()
# Out:
#    Job Title  Job Description  Rating  Company Name  Location   Size  Founded  \
# 0          1          0.00000     3.8           287         3    750     1973
# 1          0          0.00000     3.4           312        96  10000     1984
# 2          1          0.00000     4.8           162        40    750     2010
# 3          1          0.12734     3.8           212       151   3000     1965
# 4          1          0.00000     2.9            12       119    125     1998
#
#    Type of ownership  Revenue  avg_salary  age
# 0                  1     75.0        72.0   47
# 1                  0      3.5        87.5   36
# 2                  1    300.0        85.0   10
# 3                  0    250.5        76.5   55
# 4                  1    700.0       114.5   22

# %%
data['Job Description'].value_counts()
# Out:
# 0.000000    723
# 0.127340      2
# 0.050255      2
# 0.117572      1
# Name: Job Description, dtype: int64

# %%
X = data.drop('avg_salary', axis=1)
Y = data['avg_salary']

# %%
print(X)
# Out:
#      Job Title  Job Description  Rating  Company Name  Location   Size  \
# 0            1          0.00000     3.8           287         3    750
# 1            0          0.00000     3.4           312        96  10000
# 2            1          0.00000     4.8           162        40    750
# 3            1          0.12734     3.8           212       151   3000
# 4            1          0.00000     2.9            12       119    125
# ..         ...              ...     ...           ...       ...    ...
# 737          0          0.00000     3.9           128        29  10000
# 738          1          0.00000     4.4           110       116   3000
# 739          0          0.00000     2.6           264       138    750
# 740          0          0.00000     3.2           202         7     25
# 741          0          0.00000     3.6           241        18    750
#
#      Founded  Type of ownership  Revenue  age
# 0       1973                  1     75.0   47
# ...

# %%
print(Y)
# Out:
# 0       72.0
# 1       87.5
# 2       85.0
# 3       76.5
# 4      114.5
#        ...
# 737     84.5
# 738    102.5
# 739     73.5
# 740    127.5
# 741     93.5
# Name: avg_salary, Length: 728, dtype: float64

# %%
from xgboost import XGBRegressor
from sklearn import metrics
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=2)

# %%
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
import lightgbm as lgb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[135], line 3
#       1 from sklearn.svm import SVR
#       2 from sklearn.ensemble import GradientBoostingRegressor
# ----> 3 import lightgbm as lgb
#
# File /usr/local/lib/python3.11/site-packages/lightgbm/__init__.py:8
#       2 """LightGBM, Light Gradient Boosting Machine.
#       3
#       4 Contributors: https://github.com/microsoft/LightGBM/graphs/contributors.
#       5 """
#       6 from pathlib import Path
# ----> 8 from .basic import Booster, Dataset, Sequence, register_logger
#       9 from .callback import early_stopping, log_evaluation, print_evaluation, record_evaluation, reset_parameter
#      10 from .engine import CVBooster, cv, train
#
# File /usr/local/lib/python3.11/site-packages/lightgbm/basic.py:110
#     106         raise LightGBMError(lib.LGBM_GetLastError().decode('utf-8'))
# ...

# %%
model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=0)

# %%
model.fit(X_train, Y_train)
# Out:
# GradientBoostingRegressor(random_state=0)

# %%
training_data_prediction = model.predict(X_train)
r2_train = metrics.r2_score(Y_train, training_data_prediction)
r2_train
# Out:
# 0.6660828819367804

# %%
testing_data_prediction = model.predict(X_test)
r2_test = metrics.r2_score(Y_test, testing_data_prediction)
r2_test
# Out:
# 0.42682778104764707
